# %%
import os, sys, pandas as pd, numpy as np, string, json, math
from pandas.io.json import json_normalize
from random import randrange, shuffle

# %%
DATA_FOLDER = "../data/"

SYN_REPORTS_FOLDER = "../data/outputs/synthetic_reports/"

# %%
def create_metric_names(num_metrics = 100, prefixes = ["volume_sales", "value_sales", "arpu", "user_name", 
                                                       "phone_num", "usage_tier", "total_calls", "total_sms", 
                                                       "total_data", "monthly_plan", "subscriptions", 
                                                       "roaming_calls", "roaming_data", "roaming_sms", 
                                                       "volume sales", "value sales", "arpu", "user name", 
                                                       "phone num", "usage tier", "total calls", "total sms", 
                                                       "total data", "monthly plan", "subscriptions", 
                                                       "roaming calls", "roaming data", "roaming sms",
                                                      "sales(volume)", "value sales", "arpu", "user name", 
                                                       "phone num", "usage tier", "total calls", "total sms", 
                                                       "total data", "monthly plan", "subscriptions", 
                                                       "roaming calls", "data(roaming)", "roaming sms"]):
    
    """
    Creates metric names based on the prefixes provided.
    create num_metrics number of metrics totally
    """
    
    pre_len = len(prefixes)
    
    num_replica = (num_metrics//pre_len) + 1
    
    metrics_list = []
    
    for prefix in prefixes:
        
        for rep_num in range(num_replica):
            
            if len(metrics_list) >= num_metrics:
                
                break
            
            metrics_list.append(prefix + "_" + str(rep_num))
            
    
    return metrics_list

# %%
with open('../data/raw/telstra.json') as jsonfile:
    
    telstra = json.load(jsonfile)
    
telstra_df = json_normalize(telstra)

telstra_df.head()
# Out:
# /home/fractaluser/anaconda3/envs/telstra/lib/python3.6/site-packages/ipykernel_launcher.py:5: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   """
#                                                 text  \
# 0  [Not a bad deal., NOTE: Gift card can only be ...
# 1  [Pretty much the same deal they have had long ...
# 2  [Per email:, \nChristmas is a magical time of ...
# 3  [You get a free $30 sim too in the deal. Prett...
# 4  [Telstra has today unveiled its new $199 “Ulti...
#
#                                                tags                post_date  \
# 0  [ Electrical & Electronics,  Apple,  Smartwatch]   on 08/11/2018 - 11:11
# 1      [ Mobile,  Gift Card,  Phone Plan,  Telstra]   on 21/10/2019 - 20:19
# 2   [ Entertainment,  Instagrampost,  Movie Ticket]   on 07/11/2018 - 18:24
# 3                  [ Mobile,  Apple,  Mobile Phone]   on 26/12/2018 - 13:17
# 4                            [ Mobile,  Phone Plan]   on 24/07/2018 - 22:55
#
#           user            web_link  \
# 0  android iOS         ebay.com.au
# 1       ChiMot       jbhifi.com.au
# 2  Bananaramas      telstra.com.au
# 3      swapsey      telstra.com.au
# 4        bonky  channelnews.com.au
#
#                                                title
# 0  Apple Watch Series 3 38mm Cellular $458.10 Del...
# 1  Telstra 12-Month Post Paid 60GB $65 Per Month ...
# 2  10 Village/ Event Cinema Movie Vouchers for $9...
# 3  iPhone 6 32GB $329 Delivered @ Telstra (Online...
# 4  $199 P/M for Unlimited Mobile Data/Calls/SMS/M...

# %%
def create_metric_desc(df, num_metrics = 100):
    
    """
    Takes a sample data frame that should have "title" as column and 
    values in these columns should be text
    
    Returns num_metrics no of list of texts 
    
    """
    
    text_lists = df["title"].tolist()
    
    total_texts = len(text_lists)
    
    repeats = math.ceil(num_metrics / total_texts )
    
    text_lists = text_lists * repeats
    
    
    
    return text_lists[:num_metrics]

# %%
NUM_METRICS = 500

metric_names = create_metric_names(NUM_METRICS)

print(len(metric_names))

metric_descriptions = create_metric_desc(telstra_df, num_metrics=NUM_METRICS)

print(len(metric_descriptions))
# Out:
# 500
# 500

# %%
metrics_catalog_df = pd.DataFrame({"metrics": metric_names, "description": metric_descriptions})

metrics_catalog_df.sample(5)
# Out:
#             metrics                                        description
# 72    total_calls_0  Telstra Easy Control 102 Twin Cordless Phones ...
# 281  monthly plan_5  Apple Watch Series 3 Silver/Space Grey Dark Ol...
# 204     user name_0  Lifeproof iPhone 8 Plus FRE Case - Lime $25.00...
# 40      user_name_4  [NSW, VIC] $500 Gift Card for Telstra Port-in ...
# 317  roaming data_5  iPhone X Leather Folio Black $94.05 Delivered ...

# %%
metrics_catalog_df.to_csv("{}metrics_catalog_synthetic_v1_19feb20.csv".format(DATA_FOLDER + "outputs/"), index=False)

# %% [markdown]
# #### Reports Creation

# %%
column_names = create_metric_names(NUM_METRICS + 500, prefixes=["nsw", "qld", "sydney", "melbourne", 
                                                       "brisbane", "perth", "victoria", "canberra", 
                                                       "adelaid", "gold coast", "auckland"])

# %%
pd.options.display.max_rows = 1000

# %%
def _delete_files_from_folder(foldername = SYN_REPORTS_FOLDER):
    
    abs_path = os.path.abspath(SYN_REPORTS_FOLDER)
    
    print("Deleting files from {}".format(abs_path))
    
    filenames = os.listdir(abs_path)
    
    counter = 0
    
    for filename in filenames:
        
        abs_filename = os.path.join(abs_path, filename)

        try:
            os.remove(abs_filename)
            
            counter += 1
            
        except Exception as e:
            
            print("unable to delete "+ filename + "_" +str(e))
            
            pass
        
    print("{}/{} files deleted.".format(str(counter), str(len(filenames))))
    
    return

# %%
def create_reports(column_names, num_reports = 10, num_rows = 10):
    
    """
    Delete currently present reports, then create num_reports # of  excel files with num_rows
    
    Column names for eacg file will be randomly sampled from provided column names
    
    num cols per file is randomly varied to be around (len(column_names)//num_reports + 5)
    
    similarly number of rows are randomly varied for each report
    
    A string column is randomly added to each report. Values in this column will be randomly the column names themselves
    """
    
    num_columns = len(column_names)
    
    num_cols_rep = math.ceil(num_columns // num_reports) + 5
    
    reports_list = []
    
    """
    First delete all files in synthetic reports folder
    """
    _delete_files_from_folder(SYN_REPORTS_FOLDER)
    
    for rep in range(num_reports):
        
        num_columns_curr = randrange(2, num_cols_rep)
        
        string_col_num = randrange(1, num_columns_curr)
        
        num_rows_curr = randrange(2, num_rows + 5)
        
        col_nums = np.random.randint(1, num_columns, num_columns_curr).tolist()
        
        col_names = [column_names[x]for x in col_nums]
        
        string_colname = col_names[string_col_num]
        
        curr_report_df = pd.DataFrame(columns=col_names)
        
        for col in col_names:
            
            if col == string_colname:
                
                idxs = np.random.randint(1, num_columns, num_rows_curr).tolist()
                
                values = [column_names[x] for x in idxs]
                
                #print(col)
                
            else:
                
                values = np.random.rand(num_rows_curr).tolist()
            
            curr_report_df[col] = values
            
        print("{} report(s) created".format(str(rep + 1)))
        
        reports_list.append(curr_report_df)

        curr_report_df.to_excel("{}reports_synthetic_{}_v1_19feb20.xlsx".format(SYN_REPORTS_FOLDER, str(rep)), 
                                      index=False)
    
    return reports_list

# %%
df_list = create_reports(column_names, num_reports = 204, num_rows = 100)
# Out:
# Deleting files from /home/fractaluser/Narahari/Fractal/telstra_metric_buster/data/outputs/synthetic_reports
# 204/204 files deleted.
# 1 report(s) created
# 2 report(s) created
# 3 report(s) created
# 4 report(s) created
# 5 report(s) created
# 6 report(s) created
# 7 report(s) created
# 8 report(s) created
# 9 report(s) created
# 10 report(s) created
# 11 report(s) created
# 12 report(s) created
# 13 report(s) created
# 14 report(s) created
# 15 report(s) created
# 16 report(s) created
# 17 report(s) created
# 18 report(s) created
# 19 report(s) created
# 20 report(s) created
# 21 report(s) created
# 22 report(s) created
# 23 report(s) created
# 24 report(s) created
# 25 report(s) created
# 26 report(s) created
# 27 report(s) created
# 28 report(s) created
# 29 report(s) created
# 30 report(s) created
# 31 report(s) created
# 32 report(s) created
# 33 report(s) created
# 34 report(s) created
# 35 report(s) created
# 36 report(s) created
# 37 report(s) created
# 38 report(s) created
# 39 report(s) created
# 40 report(s) created
# 41 report(s) created
# 42 report(s) created
# 43 report(s) created
# 44 report(s) created
# 45 report(s) created
# 46 report(s) created
# 47 report(s) created
# 48 report(s) created
# 49 report(s) created
# 50 report(s) created
# 51 report(s) created
# 52 report(s) created
# 53 report(s) created
# 54 report(s) created
# 55 report(s) created
# 56 report(s) created
# 57 report(s) created
# 58 report(s) created
# 59 report(s) created
# 60 report(s) created
# 61 report(s) created
# 62 report(s) created
# 63 report(s) created
# 64 report(s) created
# 65 report(s) created
# 66 report(s) created
# 67 report(s) created
# 68 report(s) created
# 69 report(s) created
# 70 report(s) created
# 71 report(s) created
# 72 report(s) created
# 73 report(s) created
# 74 report(s) created
# 75 report(s) created
# 76 report(s) created
# 77 report(s) created
# 78 report(s) created
# 79 report(s) created
# 80 report(s) created
# 81 report(s) created
# 82 report(s) created
# 83 report(s) created
# 84 report(s) created
# 85 report(s) created
# 86 report(s) created
# 87 report(s) created
# 88 report(s) created
# 89 report(s) created
# 90 report(s) created
# 91 report(s) created
# 92 report(s) created
# 93 report(s) created
# 94 report(s) created
# 95 report(s) created
# 96 report(s) created
# 97 report(s) created
# 98 report(s) created
# 99 report(s) created
# 100 report(s) created
# 101 report(s) created
# 102 report(s) created
# 103 report(s) created
# 104 report(s) created
# 105 report(s) created
# 106 report(s) created
# 107 report(s) created
# 108 report(s) created
# 109 report(s) created
# 110 report(s) created
# 111 report(s) created
# 112 report(s) created
# 113 report(s) created
# 114 report(s) created
# 115 report(s) created
# 116 report(s) created
# 117 report(s) created
# 118 report(s) created
# 119 report(s) created
# 120 report(s) created
# 121 report(s) created
# 122 report(s) created
# 123 report(s) created
# 124 report(s) created
# 125 report(s) created
# 126 report(s) created
# 127 report(s) created
# 128 report(s) created
# 129 report(s) created
# 130 report(s) created
# 131 report(s) created
# 132 report(s) created
# 133 report(s) created
# 134 report(s) created
# 135 report(s) created
# 136 report(s) created
# 137 report(s) created
# 138 report(s) created
# 139 report(s) created
# 140 report(s) created
# 141 report(s) created
# 142 report(s) created
# 143 report(s) created
# 144 report(s) created
# 145 report(s) created
# 146 report(s) created
# 147 report(s) created
# 148 report(s) created
# 149 report(s) created
# 150 report(s) created
# 151 report(s) created
# 152 report(s) created
# 153 report(s) created
# 154 report(s) created
# 155 report(s) created
# 156 report(s) created
# 157 report(s) created
# 158 report(s) created
# 159 report(s) created
# 160 report(s) created
# 161 report(s) created
# 162 report(s) created
# 163 report(s) created
# 164 report(s) created
# 165 report(s) created
# 166 report(s) created
# 167 report(s) created
# 168 report(s) created
# 169 report(s) created
# 170 report(s) created
# 171 report(s) created
# 172 report(s) created
# 173 report(s) created
# 174 report(s) created
# 175 report(s) created
# 176 report(s) created
# 177 report(s) created
# 178 report(s) created
# 179 report(s) created
# 180 report(s) created
# 181 report(s) created
# 182 report(s) created
# 183 report(s) created
# 184 report(s) created
# 185 report(s) created
# 186 report(s) created
# 187 report(s) created
# 188 report(s) created
# 189 report(s) created
# 190 report(s) created
# 191 report(s) created
# 192 report(s) created
# 193 report(s) created
# 194 report(s) created
# 195 report(s) created
# 196 report(s) created
# 197 report(s) created
# 198 report(s) created
# 199 report(s) created
# 200 report(s) created
# 201 report(s) created
# 202 report(s) created
# 203 report(s) created
# 204 report(s) created

# %%
def create_cols_metric_mapping(colnames, metric_names):
    
    """
    Creates a synthetic mapping b/w colnames and metric names
    
    Assumes, more than 1 column could be mapped to a metric
    """
    
    # Introducing duplicates in metrics
    metric_names_duplicated = metric_names * 2
    
    #Random shuffle
    shuffle(metric_names_duplicated)
    
    #Sample from this duplicated randomly shuffled metric names and assign them against columns
    
    num_cols = len(colnames)
    
    sampled_metric_names = metric_names_duplicated[:num_cols]
    
    col_met_mapping = pd.DataFrame({"column_names":colnames, "metric_names":sampled_metric_names})   
    
    
    col_met_mapping.to_csv("{}col_met_mapping_v1_19feb20.csv".format(DATA_FOLDER+"outputs/"), index=False)
    
    return col_met_mapping

# %%
col_met_mapping = create_cols_metric_mapping(colnames=column_names, metric_names=metric_names)

col_met_mapping.head(5)
# Out:
#   column_names     metric_names
# 0        nsw_0     phone num_11
# 1        nsw_1      phone_num_9
# 2        nsw_2    usage_tier_11
# 3        nsw_3      user name_3
# 4        nsw_4  roaming_calls_0

# %%
col_met_mapping.metric_names.duplicated().sum()
# Out:
# 664

# %% [markdown]
# #### Users - Files -Owners mapping

# %%
names_list = telstra_df["user"].unique().tolist()

print(len(names_list))

names_list
# Out:
# 610
# ['android iOS',
#  'ChiMot',
#  'Bananaramas',
#  'swapsey',
#  'bonky',
#  'Dealma',
#  'RtN',
#  'save50',
#  'pennypincher98',
#  'readerr0r',
#  'dealbot',
#  'Tejas57',
#  'JAY13',
#  'Sanjup',
#  'Amos',
#  'deal junkie',
#  'monty168',
#  'nat why',
#  'Aethelbert',
#  'windowshopper',
#  'ravendr',
#  'SolidestVIDU',
#  'bugger off',
#  'Suju',
#  'neilpatrickharris',
#  'aiyoyo',
#  'RYZEN',
#  'Sergeant Salami',
#  'unistudent1',
#  'RogueWolf',
#  'Suoflo',
#  'Snowman1',
#  'J4N9',
#  'mooturner',
#  'jv',
#  'Nemali',
#  'Tipu',
#  'crazynic',
#  'hek666',
#  'jasonmurray',
#  'rend586',
#  'Oteta',
#  'Dud',
#  'kururii',
#  'bozbargain',
#  'kurdoxan',
#  'jake772',
#  'rocky7st',
#  'jasswolf',
#  'aaruu',
#  'tbargain',
#  'kokomo1978',
#  'humbala',
#  'Nalar',
#  'kcbworth',
#  'unknown101',
#  'Nass1',
#  'MikeKulls',
#  'rba',
#  'samsal46',
#  'Cocococo111222333',
#  'Ganda',
#  'BooYa',
#  'Yanluk',
#  'downero',
#  'singhdeals',
#  'sc00bie',
#  'lakmal',
#  'seejay80',
#  'bargain4all',
#  'Hits',
#  'Holdeningon',
#  'quinteros',
#  'mdsh',
#  'wellzi',
#  'Cheapnesssake',
#  'jc89',
#  'doweyy',
#  'Snacky',
#  'koalafied',
#  'nietzsche bargain',
#  'IMadeYouReadThis',
#  'dickiee',
#  'Luckycoupan',
#  'misterchan',
#  'TRENT86',
#  'phocks',
#  'sween64',
#  'brandogs',
#  'hamza23',
#  'BeauGiles',
#  'tightarse',
#  'cj3',
#  'djcharliek',
#  'BNR32',
#  'worker',
#  'repentiverepeater',
#  'syswong',
#  'mouski',
#  'DagBateway',
#  'Bargainaholic',
#  'gingerale95',
#  'Archsyren',
#  'Username not found',
#  'theoneandonlylml',
#  'bentley',
#  'The Wololo Wombat',
#  'CrocDundee',
#  'Jaystea',
#  'Ducatista',
#  'steedy',
#  'RimofLeo',
#  'cmdnxtt',
#  'Viper1183',
#  'jj1',
#  'Rysie',
#  'edw0000000',
#  'PolishDumbo',
#  'Make it so',
#  'HADOUKEN',
#  'markis10',
#  'Bargainbeth',
#  'dosada',
#  'Meulsie',
#  'surengiri',
#  'webtherapist',
#  'MELso',
#  'jujube32',
#  'ModiWar',
#  'Being Askhole',
#  'sc00by',
#  'lastkey',
#  'redfox1200',
#  'DoubleUKayG',
#  'uk3000',
#  'fatherchicken',
#  'sinisterdrake',
#  'alvian',
#  'Kupret',
#  'FencePost',
#  'JeffreyM',
#  'Thespottedcow',
#  'Sevenofnine',
#  'prince7',
#  'danger163',
#  'allenhori',
#  'Kikiriki',
#  'souleaterX',
#  'headphonejack',
#  'sonny08',
#  'MightyMyza',
#  'dK69',
#  'Arkanite',
#  'fastzoomzoom',
#  'edisonAU',
#  'Wizard',
#  'uzz30',
#  'vr4indian',
#  'liverpoolfan',
#  'winfan',
#  'nir184',
#  'Regie69',
#  'julesp1485',
#  'PTG Benny',
#  'newozbargainermelb',
#  'grababargain',
#  'nineninenine',
#  'gentlecrack',
#  'NakedTechPodcast',
#  'adilaksh',
#  'aspirepranesh',
#  'wry19890413',
#  'huwcar',
#  'pantsparty',
#  'YellowKnight',
#  'gill786',
#  'fezzo',
#  'Cellmate',
#  'loku123',
#  'urbancartel',
#  'downforce',
#  'Smogul',
#  'dannyc33',
#  'stickymoo',
#  'Swirlboy',
#  'pointy1',
#  'tomcat83',
#  'burningrage',
#  'CrazyBargains1',
#  'jasnkapadia',
#  'RichardL',
#  'wombomombojombo',
#  'notatall',
#  'harobed',
#  'Ryballs',
#  'cha059',
#  'dalemightypies',
#  'Thissguyy',
#  'DvD',
#  'Raz84',
#  'TaurusHead',
#  'jes',
#  'buhie',
#  'Itsagooddeal',
#  'Goldberg',
#  'TristanJ',
#  'ben1980',
#  'renaldof',
#  'symeteor',
#  'maverickjohn',
#  'mafroew',
#  'Asaiyo',
#  'Jamesph',
#  'Kaiden17',
#  'googoogaga',
#  'OzBargein',
#  'tellhimhesdreaming',
#  'greentea',
#  'tdrive',
#  'CrushJelly',
#  'enjoyinglife',
#  'bennythejet',
#  'roffey1',
#  'hopper',
#  'eggaz',
#  'agame',
#  'furythree',
#  'Taza',
#  'gcquest',
#  'netslicer',
#  'whereisthedeal',
#  'Hunter54998',
#  'mnma',
#  'StrayfireX',
#  'HoteDoge',
#  'quarrymaster',
#  'BlinkyBill',
#  'SR9',
#  'skwashd',
#  'onhunt',
#  'Clear',
#  'nyteshaiid',
#  'sea1',
#  'weusm',
#  'TightAsianJew',
#  'Wardaddy',
#  'DaTa',
#  'Sam4dealz',
#  'butwhy',
#  'supert1ght',
#  'Matt P',
#  'Sleepy24seven',
#  'ihavecentsnotsense',
#  'Juzzy96',
#  'Rubber Duck',
#  'carva848',
#  'ablqadir',
#  'ClumpyGinger',
#  'FayQ',
#  'Secepatnya',
#  'Quantumcat',
#  'haha',
#  'kane9522',
#  'developersteve',
#  'currentfad',
#  'zack1502',
#  'dingdong555',
#  'evolution-flip',
#  'XoiThit',
#  '17833',
#  'amazonaddict',
#  'jrt2020',
#  'Michaellm84',
#  'Sp Sukhy',
#  'KM2018',
#  'pingz',
#  'chubbygeek',
#  'bargainHunterAU',
#  'MiCCAS',
#  'techgeek69',
#  'OhMaJuck',
#  'Victor10',
#  'winteragain',
#  'zealmax',
#  'slowy',
#  'padfoot07',
#  'DeadManiac',
#  'Stylez',
#  'vishal9696',
#  'firstworldproblems',
#  'zedroid',
#  'snappy1234',
#  'lowDmax',
#  'CDG',
#  'sryanwib',
#  'Jase2801',
#  'tonytone',
#  'pluto',
#  'G-Dynamite',
#  'OzBargin',
#  'hellomellop',
#  'samualli',
#  'scubacoles',
#  'kunafpls',
#  'nats',
#  'Fungsta',
#  'onebee',
#  'DrPotato',
#  'suicine94',
#  'mkhannah',
#  'dealman',
#  'zixtee',
#  'Bearosaurus',
#  'banzini',
#  'whaleoilbeefhooked',
#  'enayet',
#  'John Stone',
#  'djfish31',
#  'CodeXD',
#  'flickr',
#  'Bargain Seeker',
#  'Becausebargains',
#  'Thundaja',
#  'Meque',
#  'Turd',
#  'OSA',
#  'chewkl',
#  'bargaindude',
#  'eug',
#  'iratepirate',
#  'superforever',
#  'hao1989',
#  'TheProf',
#  'lml',
#  '3zzy',
#  'dazweeja',
#  'His_Holiness',
#  'Savas',
#  'DeedubMelbourne',
#  'realfancyman',
#  'closey',
#  'thriftysach',
#  'Save Medicare',
#  'Jake17',
#  'lovbargain',
#  'Panadol',
#  'paulj13',
#  'ccwwayne',
#  'aeon',
#  'uggugg',
#  'tonester',
#  'aoujay51',
#  'CandyMan',
#  'WoodenSpoon',
#  'ChippyD',
#  'quop',
#  'sw0rdy',
#  'ShamelessBargains',
#  'super bargain',
#  'truffles',
#  'oz-stef',
#  'Spackbace',
#  'GreatWhiteHunter',
#  'SocietyBox',
#  '9race',
#  'gerdschenkel',
#  'Roary',
#  'elusive',
#  'Phoenixsun6',
#  'matttttt',
#  'garycheese',
#  'exit',
#  'snowcold',
#  'televisi',
#  'trickypie',
#  'Malbies',
#  'punkman',
#  'bobswinkle',
#  'ra2er',
#  'Shibuya',
#  'Presjar',
#  'Mijak',
#  'askzxy',
#  'unco',
#  'Neilu',
#  'reslo',
#  'ssander',
#  'acrediblesource',
#  'hikaru78',
#  'Apple96',
#  'bez-54',
#  'theBestBastion',
#  'cheapaschups',
#  'samehada',
#  'Mattwilko',
#  'Evio',
#  'neverowsky',
#  'JJJ',
#  'nocure',
#  'dwhes',
#  'mikhaelkin',
#  'krouton24',
#  'bxpressiv',
#  'R6',
#  'b4rgainhunter',
#  '94falcon',
#  'freefall101',
#  'thewarden',
#  'agentsabet',
#  'micle',
#  'cmyk',
#  'luxx',
#  'apptrack',
#  'gum7by',
#  'forumninja',
#  'Chthonic',
#  'Chuppa',
#  'madnesskid',
#  'annarchon',
#  'giles',
#  'ts13',
#  'cdaddy',
#  'AustinZ',
#  'Wokstar',
#  'spiderdash',
#  'Nuggets',
#  'snagseb',
#  'michaelc33',
#  'McBanny',
#  '2stroksmokr',
#  'Shivan1403',
#  'Wick',
#  'matice',
#  'hurray',
#  'superApple',
#  'Goodfellha',
#  'A2E2',
#  'Nero',
#  'NejiXSan',
#  'frogger081',
#  'interfreak',
#  'Olokun',
#  'ElusiveA',
#  'flylin',
#  'pyramid',
#  'Azif',
#  'easternculture',
#  'jasperthegoat',
#  'OzSikh',
#  'barginsarelife',
#  'crazyj',
#  'yukonit',
#  'HSV_GTS',
#  'John Dough',
#  'kaBargain',
#  'brendanl',
#  'jjayoen',
#  'BigSalad',
#  'Xenatos',
#  'Aceboy884',
#  'sam-1966',
#  'eversmile',
#  'BargainOmaniac',
#  'akd',
#  'monty.melb',
#  'romaau',
#  'ringo9',
#  'dalvin',
#  'LolwutMikka',
#  'salesberg',
#  'dasher86',
#  'Lion007',
#  'Ali1988',
#  'chetan',
#  'claud0902',
#  'nicois',
#  'vikingbrad',
#  'BTB',
#  'Willy Bargin',
#  'kanad',
#  'Brotality',
#  'Cheesie',
#  'durx',
#  'legendary-noob',
#  'Macca87',
#  'jayc',
#  'Infinite Monkee',
#  'theearth',
#  'triplezzb',
#  'javajo',
#  'huey',
#  'monday24',
#  'roseyhead',
#  'Garagesale',
#  'peuwayaqdq',
#  'blazer',
#  'gpritchard',
#  'Balls',
#  'odyssi',
#  'wherestheid',
#  'Woodyg22',
#  'petros0',
#  'ozbargained',
#  'al8',
#  'nismo',
#  'franek',
#  'satanguy',
#  'ahara',
#  'samlor',
#  'Geewhizz',
#  'dannyboi',
#  'twosixfiveoh',
#  'lac0449',
#  'Sooty',
#  'ShortyX',
#  'Sydneyian',
#  'bigsue19',
#  'nicksman',
#  'baronseng',
#  'firepowered',
#  'swimmingtoad',
#  'Hippy',
#  'steven823',
#  'wowdeal',
#  'scotty',
#  'Jaxx',
#  'ozzie',
#  'randomdude',
#  'neil',
#  'Xandak',
#  'tassie Pete',
#  'ryangoal',
#  'cciputra',
#  'DarkProject',
#  'cura',
#  'reebar',
#  'melozb',
#  'm13',
#  'x-factors',
#  'oringal',
#  'krazed15',
#  'bteq',
#  'ruraro',
#  'Ambiguous',
#  'ca6leguy',
#  'Alzori',
#  'Telstra',
#  'chickachicka',
#  'iceborg',
#  'regenade',
#  'Hintswen',
#  'lukelegend',
#  'catmao',
#  'zyc3',
#  'ebayaddict',
#  'wasanewguy',
#  'Jeffreylin',
#  'Superlawyer',
#  'antzz',
#  'ma7trlb',
#  'truebargains',
#  'dan199',
#  'anthony',
#  'Calmerancer',
#  'mr_vino89',
#  'ChickenAdobo',
#  'narbe',
#  'Lavec',
#  'Alias2000',
#  'bmwardo',
#  'wfdTamar',
#  '00',
#  'douglasac10',
#  'madmouse58',
#  'protecon',
#  'safwanc',
#  '777',
#  'stewy',
#  'corgi',
#  'Marrk',
#  'bryans',
#  'keano1989',
#  'Floopington',
#  'pastapins',
#  'tfb',
#  'riviera',
#  'POWERevolution',
#  'grange',
#  'Souljarh',
#  'Dealayed',
#  'stirlo',
#  'rayboy2006',
#  'PS3God',
#  'moocher',
#  'rewstar',
#  'Mysterious',
#  'Axelstrife',
#  'Zfan111222',
#  'wisc',
#  'abzolutely',
#  'HAL',
#  'sourdawg',
#  'TelecomAustralia',
#  'Mckenzie',
#  'Megamind',
#  'irajohn90',
#  'holofernes',
#  'bravohe',
#  'brich1980',
#  'Food']

# %%
report_names = os.listdir(SYN_REPORTS_FOLDER)

# %%
def create_user_rep_owner_mapping(names_list, report_names):
    
    """
    Creates report - owners mapping
    and report - users mapping
    
    A owner can be mapped to multiple reports
    
    Each report will have multiple users in a many to many fashion
    """
    
    num_reports = len(report_names)
    
    num_names = len(names_list)
    
    #Duplicate usernames and randomly assign them to reports
    
    num_names_rep = math.ceil(num_reports / num_names) + 50
    
    names_list_dup = names_list * num_names_rep
    
    shuffle(names_list_dup)
    
    owner_names = names_list_dup[:num_reports]
    
    #Duplicate report names and randomly assign them to duplicated random users
    
    num_rep_rep = math.ceil(num_names / num_reports) + 3
    
    reports_list_dup = report_names * num_rep_rep
    
    shuffle(reports_list_dup)
    
    names_mult_factor = math.ceil(len(reports_list_dup) // num_names) + 1
    
    names_list_dup2 = names_list * names_mult_factor
    
    shuffle(names_list_dup2)
    
    user_names_list = names_list_dup2[: len(reports_list_dup)]
    
    owners_df = pd.DataFrame({"Reports": report_names, "Owners":owner_names})
    
    users_df = pd.DataFrame({"Reports": reports_list_dup, "Users":user_names_list})
    
    users_df.drop_duplicates(inplace=True)
    
    users_df.sort_values("Reports", inplace=True)
    
    owners_df.sort_values("Reports", inplace=True)
    
    users_df.reset_index(drop=True, inplace=True)
    
    print(users_df.shape)
    
    owners_df.to_csv("{}rep_owner_mapping_v1_19feb20.csv".format(DATA_FOLDER + "outputs/"), index=False)
    
    users_df.to_csv("{}rep_users_mapping_v1_19feb20.csv".format(DATA_FOLDER + "outputs/"), index=False)
    
    
    return [users_df, owners_df]

# %%
users_df, owners_df = create_user_rep_owner_mapping(names_list, report_names)

users_df
# Out:
# (1219, 2)
#                                   Reports          Users
# 0     reports_synthetic_0_v1_19feb20.xlsx     rayboy2006
# 1     reports_synthetic_0_v1_19feb20.xlsx     interfreak
# 2     reports_synthetic_0_v1_19feb20.xlsx       Jase2801
# 3     reports_synthetic_0_v1_19feb20.xlsx            HAL
# 4     reports_synthetic_0_v1_19feb20.xlsx  Bargainaholic
# ...                                   ...            ...
# 1214  reports_synthetic_9_v1_19feb20.xlsx           luxx
# 1215  reports_synthetic_9_v1_19feb20.xlsx       sryanwib
# 1216  reports_synthetic_9_v1_19feb20.xlsx          Savas
# 1217  reports_synthetic_9_v1_19feb20.xlsx       TristanJ
# 1218  reports_synthetic_9_v1_19feb20.xlsx        bmwardo
#
# [1219 rows x 2 columns]

# %%
print(owners_df.Owners.duplicated().sum())
# Out:
# 33

# %%
owners_df
# Out:
#                                    Reports             Owners
# 99     reports_synthetic_0_v1_19feb20.xlsx             Suoflo
# 49   reports_synthetic_100_v1_19feb20.xlsx          PTG Benny
# 28   reports_synthetic_101_v1_19feb20.xlsx             sc00by
# 150  reports_synthetic_102_v1_19feb20.xlsx            paulj13
# 167  reports_synthetic_103_v1_19feb20.xlsx            McBanny
# 11   reports_synthetic_104_v1_19feb20.xlsx        iratepirate
# 103  reports_synthetic_105_v1_19feb20.xlsx             crazyj
# 153  reports_synthetic_106_v1_19feb20.xlsx              giles
# 164  reports_synthetic_107_v1_19feb20.xlsx            lastkey
# 12   reports_synthetic_108_v1_19feb20.xlsx             enayet
# 59   reports_synthetic_109_v1_19feb20.xlsx        Bananaramas
# 115   reports_synthetic_10_v1_19feb20.xlsx         frogger081
# 166  reports_synthetic_110_v1_19feb20.xlsx            paulj13
# 174  reports_synthetic_111_v1_19feb20.xlsx        Sevenofnine
# 144  reports_synthetic_112_v1_19feb20.xlsx              Savas
# 131  reports_synthetic_113_v1_19feb20.xlsx            zealmax
# 111  reports_synthetic_114_v1_19feb20.xlsx                jj1
# 14   reports_synthetic_115_v1_19feb20.xlsx     theBestBastion
# 168   reports_synthetic_58_v1_19feb20.xlsx              Meque
# 119   reports_synthetic_59_v1_19feb20.xlsx        Hunter54998
# 172    reports_synthetic_5_v1_19feb20.xlsx             alvian
# 46    reports_synthetic_60_v1_19feb20.xlsx         monty.melb
# 18    reports_synthetic_61_v1_19feb20.xlsx     dalemightypies
# 45    reports_synthetic_62_v1_19feb20.xlsx             Jake17
# 100   reports_synthetic_63_v1_19feb20.xlsx         StrayfireX
# 169   reports_synthetic_64_v1_19feb20.xlsx           sam-1966
# 55    reports_synthetic_65_v1_19feb20.xlsx             Matt P
# 20    reports_synthetic_66_v1_19feb20.xlsx             Smogul
# 162   reports_synthetic_67_v1_19feb20.xlsx              Nalar
# 1     reports_synthetic_68_v1_19feb20.xlsx            pyramid
# 198   reports_synthetic_69_v1_19feb20.xlsx          readerr0r
# 90     reports_synthetic_6_v1_19feb20.xlsx         BlinkyBill
# 157   reports_synthetic_70_v1_19feb20.xlsx        deal junkie
# 21    reports_synthetic_71_v1_19feb20.xlsx            Macca87
# 32    reports_synthetic_72_v1_19feb20.xlsx          krouton24
# 73    reports_synthetic_73_v1_19feb20.xlsx            Nuggets
# 9     reports_synthetic_74_v1_19feb20.xlsx             steedy
# 176   reports_synthetic_75_v1_19feb20.xlsx            downero
# 64    reports_synthetic_76_v1_19feb20.xlsx         CrocDundee
# 116   reports_synthetic_77_v1_19feb20.xlsx           tonytone
# 19    reports_synthetic_78_v1_19feb20.xlsx          triplezzb
# 85    reports_synthetic_79_v1_19feb20.xlsx           ElusiveA
# 82     reports_synthetic_7_v1_19feb20.xlsx           aoujay51
# 175   reports_synthetic_80_v1_19feb20.xlsx           apptrack
# 138   reports_synthetic_81_v1_19feb20.xlsx            mafroew
# 146   reports_synthetic_82_v1_19feb20.xlsx              giles
# 26    reports_synthetic_83_v1_19feb20.xlsx         Zfan111222
# 76    reports_synthetic_84_v1_19feb20.xlsx                HAL
# 58    reports_synthetic_85_v1_19feb20.xlsx  neilpatrickharris
# 183   reports_synthetic_86_v1_19feb20.xlsx         lovbargain
# 15    reports_synthetic_87_v1_19feb20.xlsx               nats
# 180   reports_synthetic_88_v1_19feb20.xlsx          Spackbace
# 47    reports_synthetic_89_v1_19feb20.xlsx              Raz84
# 193    reports_synthetic_8_v1_19feb20.xlsx              giles
# 31    reports_synthetic_90_v1_19feb20.xlsx           greentea
# 86    reports_synthetic_91_v1_19feb20.xlsx         vishal9696
# 108   reports_synthetic_92_v1_19feb20.xlsx            lastkey
# 70    reports_synthetic_93_v1_19feb20.xlsx         Aethelbert
# 142   reports_synthetic_94_v1_19feb20.xlsx            ShortyX
# 155   reports_synthetic_95_v1_19feb20.xlsx           monday24
# 66    reports_synthetic_96_v1_19feb20.xlsx           BigSalad
# 79    reports_synthetic_97_v1_19feb20.xlsx         souleaterX
# 135   reports_synthetic_98_v1_19feb20.xlsx           bigsue19
# 75    reports_synthetic_99_v1_19feb20.xlsx                777
# 171    reports_synthetic_9_v1_19feb20.xlsx           protecon
